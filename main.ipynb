# %%
import matplotlib.pyplot as plt
import util as util
import kernal as kernal

# %%
train_path = 'data/ds5_train.csv'
test_path = 'data/ds5_test.csv'

# %%
x_train, y_train = util.load_csv(train_path)
x_test, y_test = util.load_csv(test_path)

# %%
plt.scatter(x_train[y_train==1, 0], x_train[y_train==1, 1], marker  = '*', c = 'green', label = 'one')
plt.scatter(x_train[y_train==0, 0], x_train[y_train==0, 1], marker  = 'o', c = 'orange', label = 'zero')
plt.legend()
plt.title('Train Map')
plt.show()

# %%
learning_rate = 0.001
kernal.main(learning_rate)
